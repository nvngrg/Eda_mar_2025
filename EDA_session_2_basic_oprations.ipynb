# %% [markdown]
# # ============= WORKING ON PREDIFINE DATASET ==========

# %% [markdown]
# ## Dataset name is: Visadataset--->

# %% [markdown]
# **1. import the required pakckages**

# %%
import pandas as pd # for dataframe oprations
import numpy as np # for maths oprations 
import matplotlib.pyplot as plt # for ploting the graph
import seaborn as sns # for ploting advance graph

# %% [markdown]
# ## Read the data
#
# - Here we are readinng **visa dataset** which is **csv file** store on **dataset** folder
#
# - directory
# - file name
# - extenction

# %%
path=r"C:\Users\Admin\Documents\naresh IT\EDA(EXPOLRETREE DATA  ANALYSIS)\Visadataset.csv"

# %%
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
bank_path=r"C:\Users\Admin\Documents\naresh IT\datafiles\bank.csv"

# %%
pd.read_csv(bank_path)
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %% [markdown]
# - on the above cell we saw that all the data is on a single cell
#
# - and data is mixed, but we can observed that the data is sapreted by semicolon (";")
#
# - in feture it could be anything like , - : ; $ & *
#
#
# - so that we can read the data as dataframe by applying- **separator**
#
#     - **,sep=";"**

# %%
bank_df=pd.read_csv(bank_path,sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
dir(visa_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %% [markdown]
# ### head method----> df.head()
#
# - pakege_name.method_name()

# %%
visa_df.head() # by default 5 rows
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %% [markdown]
# #### tail method---> tail(n)
# - will show bottom n row, if n not define by default show 5 bottom row
#
# - dataset.tail(n)

# %%
visa_df.tail() # by default bottom 5 rows
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.tail(10) # now show bottom 10 row
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %% [markdown]
# #### shape attribute---.shape
#
# - will show no.of row and columns

# %%
visa_df.shape # its a attribute not a method so not need to provide () after shape.
# Out:
# (25480, 12)

# %%
print(f"The no. of rows are: {visa_df.shape[0]}") # coz its a tuple
print(f"The no. of columns are: {visa_df.shape[1]}")
# Out:
# The no. of rows are: 25480
# The no. of columns are: 12

# %% [markdown]
# #### size attribute---> **.size**
#
# - it shows total no of values it have
#
# - rows * columns

# %%
visa_df.size
# Out:
# 305760

# %%
visa_df.shape[0]*visa_df.shape[1] # 25480*12
# Out:
# 305760

# %%
print(f'Total no of elements are: { visa_df.size}')
# Out:
# Total no of elements are: 305760

# %% [markdown]
# #### columns
#
# - show name of every columns, using indexing
#
# - so by using index we can show the name individually

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.columns[0]
# Out:
# 'case_id'

# %%
len(visa_df.columns) # show no of columns
# Out:
# 12

# %%
len(visa_df) # show no of rows
# Out:
# 25480

# %% [markdown]
# #### dtypes ---> dataset.dtypes
#
# - will show all columns along with it's datatype
#
# - object meance string data type(categorical)
#
# - int64, float64 are (numerical datatype)
#
# - dtypes alwase gives in serise result

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **task-1**
#
# - i want to create two list
#
# - One is categorical column list
#
# - second one is Numerical column list
#
# - using dtype

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# **It is sowing result into a series**
#
# - so, whenevere you want to create any list from series
#
# - First convert the series into a dictionary
#
# - now it becomes key:value pair
#
# - itrate dictionary through for loop
#
# - if value=='object' type, keep on string list
#
# - else keep in numeric list

# %%
data_type=visa_df.dtypes
dict(data_type)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
cat=[]
num=[]
for i,j in dict(data_type).items(): # The .items() method is used with dictionaries to return key-value pairs as tuples.
    if j=='object': # if value is object 
        cat.append(i) # add to cat list
    else:
        num.append(i) # otherwise add to num list
        
print(f"categorical columns are: {cat}")
print()
print(f"numerical columns are:{num} ")
# Out:
# categorical columns are: ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
#
# numerical columns are:['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# ### Using list comprehension

# %%
string=[i for i,j in dict(data_type).items() if j=='object' ]
numerical=[i for i,j in dict(data_type).items() if j!='object' ]
print(f"categorical columns are: {string}")
print()
print(f"numerical columns are:{numerical} ")
# Out:
# categorical columns are: ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
#
# numerical columns are:['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# - **now using these two list we will create a dataframe**

# %%
len(cat),len(num)
# Out:
# (9, 3)

# %% [markdown]
# - we can not create a dataframe using these two list.
#
# - because these two list are not in equle length.
#
# - we need to m ake these two list in equle length
#
#   - but not requir cos can't chang original DataFrame

# %% [markdown]
# **Create columns dataframe**

# %%
num_df=pd.DataFrame(num,columns=['Numerical_column'])
num_df.to_csv('numerical_column_DF.csv',index=False)
pd.read_csv(r'numerical_column_DF.csv')
# Out:
#   Numerical_column
# 0  no_of_employees
# 1      yr_of_estab
# 2  prevailing_wage

# %%
cat_df=pd.DataFrame(cat,columns=['Categorical_column'])
cat_df.to_csv('categorical_column_DF.csv',index=False)
pd.read_csv(r'categorical_column_DF.csv')
# Out:
#       Categorical_column
# 0                case_id
# 1              continent
# 2  education_of_employee
# 3     has_job_experience
# 4  requires_job_training
# 5   region_of_employment
# 6           unit_of_wage
# 7     full_time_position
# 8            case_status

# %% [markdown]
# **Tast no.- 2**

# %%
data_type=dict(visa_df.dtypes)
data_type
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
col_name=[]
d_type=[]
for i in data_type.items():
    col_name.append(i[0])
    d_type.append(i[1])
    
print(col_name)
print(d_type)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'no_of_employees', 'yr_of_estab', 'region_of_employment', 'prevailing_wage', 'unit_of_wage', 'full_time_position', 'case_status']
# [dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'), dtype('O'), dtype('O'), dtype('O')]

# %%
data_info=pd.DataFrame(zip(col_name,d_type),columns=['cloumns name','data type'])
data_info
# Out:
#              cloumns name data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
data_info.to_csv('data_info.csv',index=False)
pd.read_csv(r'data_info.csv')
# Out:
#              cloumns name data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
# all in one 

col,dt=[],[]
for i in dict(visa_df.dtypes).items():
    col.append(i[0])
    dt.append(i[1])

pd.DataFrame(zip(col,dt),columns=['Column_Name','Data_Type']).to_csv('Data_inmformation.csv',index=False)
pd.read_csv(r'Data_inmformation.csv')
# Out:
#               Column_Name Data_Type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# ### Seps to EDA
#
# - whatever raw data make lists
#
# - From thos lists make DataFrame
#
# - Frome those Datafame make .CSV file

# %% [markdown]
# **Task-3**
#
# **We can creat a dataframe using dictionary also**

# %%
dict1={'Name':['Ram','Shyam','Mohan','Sohan'],
      'Age':[10,20,30,40]}
dict1
# Out:
# {'Name': ['Ram', 'Shyam', 'Mohan', 'Sohan'], 'Age': [10, 20, 30, 40]}

# %%
pd.DataFrame(dict1)# easist way to creatre a dataframe
# Out:
#     Name  Age
# 0    Ram   10
# 1  Shyam   20
# 2  Mohan   30
# 3  Sohan   40

# %% [markdown]
# - The advantage is here to no need to provide column name here
#
# - Automaticaly keys behaive as column name

# %% [markdown]
# ### task-4--> Create a dictionare from list and then make a dataframe
#
# - We have 2 list here
#
# - cols and num
#
# - Creata a dictionary with these two list
#
# - And make a Dataframe

# %%
info_dict={}
info_dict['columns']=col
info_dict['data type']=dt
info_dict
# Out:
# {'columns': ['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'no_of_employees',
#   'yr_of_estab',
#   'region_of_employment',
#   'prevailing_wage',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  'data type': [dtype('O'),
#   dtype('O'),
#   dtype('O'),
#   dtype('O'),
#   dtype('O'),
#   dtype('int64'),
#   dtype('int64'),
#   dtype('O'),
#   dtype('float64'),
#   dtype('O'),
#   dtype('O'),
#   dtype('O')]}

# %%
pd.DataFrame(info_dict)
# Out:
#                   columns data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
# Dataframe name: visa_df

visa_df.select_dtypes(include="object")
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# # task
#
# 1. list to dataframe
#
# 2. Dictionary to dataframe
#
# 3. List to dictionary, dict to df
#
# 4. dict to list, list to df
#
# 5. using method

# %% [markdown]
# **Task--1--> list to DF**

# %%
l1=['mon','tue','wed','thu','fri','sat','sun']
l2=['python','staticts','EDA',10,20.30,True,2+3j]
df2=pd.DataFrame(zip(l1,l2),columns=['Days','Values'])
df2.to_csv('days_value.csv',index=False)
pd.read_csv('days_value.csv')
# Out:
#   Days    Values
# 0  mon    python
# 1  tue  staticts
# 2  wed       EDA
# 3  thu        10
# 4  fri      20.3
# 5  sat      True
# 6  sun    (2+3j)

# %%
dv=pd.read_csv('days_value.csv')
dv.dtypes
# Out:
# Days      object
# Values    object
# dtype: object

# %%
day_num=[1,2,3,4,5,6,7]
dv['day number']=day_num

# %%
dv
# Out:
#   Days    Values  day number
# 0  mon    python           1
# 1  tue  staticts           2
# 2  wed       EDA           3
# 3  thu        10           4
# 4  fri      20.3           5
# 5  sat      True           6
# 6  sun    (2+3j)           7

# %%
dv.dtypes
# Out:
# Days          object
# Values        object
# day number     int64
# dtype: object

# %%
dv.drop('Values',inplace=True,axis=1)

# %%
dv
# Out:
#   Days  day number
# 0  mon           1
# 1  tue           2
# 2  wed           3
# 3  thu           4
# 4  fri           5
# 5  sat           6
# 6  sun           7

# %% [markdown]
# **Task--2 Dict to DF**

# %%
emp_dict={}
emp_dict['Days']=l1
emp_dict['day number']=day_num
emp_dict
# Out:
# {'Days': ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun'],
#  'day number': [1, 2, 3, 4, 5, 6, 7]}

# %%
pd.DataFrame(emp_dict)
# Out:
#   Days  day number
# 0  mon           1
# 1  tue           2
# 2  wed           3
# 3  thu           4
# 4  fri           5
# 5  sat           6
# 6  sun           7

# %% [markdown]
# **Task--3 take a DATASET then List to dict, dict-DF**

# %%
ds=pd.read_csv(r"C:\Users\Admin\Documents\naresh IT\EDA(EXPOLRETREE DATA  ANALYSIS)\dataset-1.csv")
ds
# Out:
#             id        name     id_2  startDay startTime     endDay   endTime  \
# 0      1040000  Montgomery       -1    Monday  05:00:00  Wednesday  10:00:00
# 1      1040010       Black       -1    Monday  10:00:00     Friday  15:00:00
# 2      1040020     Emerald       -1  Thursday  15:00:00     Friday  19:00:00
# 3      1040030       Foley       -1    Monday  19:00:00     Friday  23:59:59
# 4      1050000    Whittier  1050001  Saturday  00:00:00     Sunday  23:59:59
# ...        ...         ...      ...       ...       ...        ...       ...
# 39509  1031012     Baldwin  1031030    Monday  19:00:00     Friday  23:59:59
# 39510  1031012     Baldwin  1031032  Saturday  00:00:00     Sunday  23:59:59
# 39511  1031014    Thickson  1031016  Saturday  00:00:00     Sunday  23:59:59
# 39512  1031014    Thickson  1031018    Monday  05:00:00  Wednesday  10:00:00
# 39513  1031014    Thickson  1031020    Monday  10:00:00     Friday  15:00:00
#
# ...

# %%
ds.head() # top 5 row
# Out:
#         id        name     id_2  startDay startTime     endDay   endTime  \
# 0  1040000  Montgomery       -1    Monday  05:00:00  Wednesday  10:00:00
# 1  1040010       Black       -1    Monday  10:00:00     Friday  15:00:00
# 2  1040020     Emerald       -1  Thursday  15:00:00     Friday  19:00:00
# 3  1040030       Foley       -1    Monday  19:00:00     Friday  23:59:59
# 4  1050000    Whittier  1050001  Saturday  00:00:00     Sunday  23:59:59
#
#    able2Hov2  able2Hov3  able3Hov2  able3Hov3  able5Hov2  able5Hov3  \
# 0        3.0        3.0       -1.0         -1          3          3
# 1        6.0        6.0       -1.0         -1          6          6
# 2        3.0        3.0       -1.0         -1          3          3
# 3        6.0        6.0       -1.0         -1          6          6
# 4        6.0        6.0        NaN         -1          6          6
#
#    able4Hov2  able4Hov3
# 0          3          3
# 1          6          6
# 2          3          3
# ...

# %%
ds.tail() # bottom 5 rows
# Out:
#             id      name     id_2  startDay startTime     endDay   endTime  \
# 39509  1031012   Baldwin  1031030    Monday  19:00:00     Friday  23:59:59
# 39510  1031012   Baldwin  1031032  Saturday  00:00:00     Sunday  23:59:59
# 39511  1031014  Thickson  1031016  Saturday  00:00:00     Sunday  23:59:59
# 39512  1031014  Thickson  1031018    Monday  05:00:00  Wednesday  10:00:00
# 39513  1031014  Thickson  1031020    Monday  10:00:00     Friday  15:00:00
#
#        able2Hov2  able2Hov3  able3Hov2  able3Hov3  able5Hov2  able5Hov3  \
# 39509       11.0       11.0        4.0          4         11         11
# 39510       11.0       11.0        4.0          4         11         11
# 39511       11.0       11.0        4.0          4         11         11
# 39512        8.0        8.0        4.0          4          8          8
# 39513       11.0       11.0        4.0          4         11         11
#
#        able4Hov2  able4Hov3
# 39509         11         11
# ...

# %%
ds.shape # no of rows and column
# Out:
# (39514, 15)

# %%
ds.size # total no of element
# Out:
# 592710

# %%
ds.columns # names of all columns
# Out:
# Index(['id', 'name', 'id_2', 'startDay', 'startTime', 'endDay', 'endTime',
#        'able2Hov2', 'able2Hov3', 'able3Hov2', 'able3Hov3', 'able5Hov2',
#        'able5Hov3', 'able4Hov2', 'able4Hov3'],
#       dtype='object')

# %%
len(ds.columns) # total n o of columns
# Out:
# 15

# %%
ds.dtypes
# Out:
# id             int64
# name          object
# id_2           int64
# startDay      object
# startTime     object
# endDay        object
# endTime       object
# able2Hov2    float64
# able2Hov3    float64
# able3Hov2    float64
# able3Hov3      int64
# able5Hov2      int64
# able5Hov3      int64
# able4Hov2      int64
# able4Hov3      int64
# dtype: object

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39514 entries, 0 to 39513
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         39514 non-null  int64
#  1   name       39514 non-null  object
#  2   id_2       39514 non-null  int64
#  3   startDay   39514 non-null  object
#  4   startTime  39514 non-null  object
#  5   endDay     39514 non-null  object
#  6   endTime    39514 non-null  object
#  7   able2Hov2  37708 non-null  float64
#  8   able2Hov3  37709 non-null  float64
#  9   able3Hov2  37709 non-null  float64
#  10  able3Hov3  39514 non-null  int64
#  11  able5Hov2  39514 non-null  int64
#  12  able5Hov3  39514 non-null  int64
#  13  able4Hov2  39514 non-null  int64
#  14  able4Hov3  39514 non-null  int64
# dtypes: float64(3), int64(7), object(5)
# memory usage: 4.5+ MB

# %%
colm,dtyp=[],[]
dt=ds.dtypes
for i in dict(dt).items():
    colm.append(i[0])
    dtyp.append(i[1])
df=pd.DataFrame(zip(colm,dtyp),columns=['col_name','data_typ'])
df.to_csv('dataset1_dt.csv', index=False)
pd.read_csv('dataset1_dt.csv')
# Out:
#      col_name data_typ
# 0          id    int64
# 1        name   object
# 2        id_2    int64
# 3    startDay   object
# 4   startTime   object
# 5      endDay   object
# 6     endTime   object
# 7   able2Hov2  float64
# 8   able2Hov3  float64
# 9   able3Hov2  float64
# 10  able3Hov3    int64
# 11  able5Hov2    int64
# 12  able5Hov3    int64
# 13  able4Hov2    int64
# 14  able4Hov3    int64

# %% [markdown]
# **Task--> 4. dict to list, list to df**

# %%
print(colm)
print()
print(dtyp)
# Out:
# ['id', 'name', 'id_2', 'startDay', 'startTime', 'endDay', 'endTime', 'able2Hov2', 'able2Hov3', 'able3Hov2', 'able3Hov3', 'able5Hov2', 'able5Hov3', 'able4Hov2', 'able4Hov3']
#
# [dtype('int64'), dtype('O'), dtype('int64'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64'), dtype('int64')]

# %%
dt_dict={}
dt_dict['col_name']=colm
dt_dict['d_type']=dtyp
pd.DataFrame(dt_dict)
# Out:
#      col_name   d_type
# 0          id    int64
# 1        name   object
# 2        id_2    int64
# 3    startDay   object
# 4   startTime   object
# 5      endDay   object
# 6     endTime   object
# 7   able2Hov2  float64
# 8   able2Hov3  float64
# 9   able3Hov2  float64
# 10  able3Hov3    int64
# 11  able5Hov2    int64
# 12  able5Hov3    int64
# 13  able4Hov2    int64
# 14  able4Hov3    int64

# %% [markdown]
# **Task--> 5 using pre-define method**

# %%
cat_col=ds.select_dtypes(include='object').columns
num_col=ds.select_dtypes(exclude='object').columns
print(f"categorical columns are: {cat_col}")
print()
print(f"numerical columns are: {num_col}")
# Out:
# categorical columns are: Index(['name', 'startDay', 'startTime', 'endDay', 'endTime'], dtype='object')
#
# numerical columns are: Index(['id', 'id_2', 'able2Hov2', 'able2Hov3', 'able3Hov2', 'able3Hov3',
#        'able5Hov2', 'able5Hov3', 'able4Hov2', 'able4Hov3'],
#       dtype='object')

# %% [markdown]
# ### Find no of categorical and numerical columns

# %%
cat_col=len(ds.select_dtypes(include='object').columns)
cat_col
# Out:
# 5

# %%
num_col=len(ds.select_dtypes(exclude='object').columns)
num_col
# Out:
# 10

# %% [markdown]
# ### isnull method-- isnull()
#
# - null means element is missed
#
# - contain missing value
#
# - isnull ==> we are asking to the computer, valume or fild is missed or not?
#
# - then computer will give `True or False`
#
# - True: yes value missed
#
# - False: no not missed
#
# - $$syntax$$-->`DataFrameName.isnull()`

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# **Count how many missing value**
#
# - show column name with number of missing value.
#
# - $$syntax$$--> `DataFrameName.isnull.sum()`

# %%
visa_df.isnull().sum() # 0 : no missing value
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_df.isna().sum() # asme as avove isnull()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# ### info method---> info()
#
# - provide all information related to dataset
#
#     1. How many rows(entries)
#
#     2. How many columns
#
#     3. columns name with non-null count along with data type
#
#     4. How many float cloumns, int columns, categorical columns
#
#     5. How much memory required to save dataset.

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# ### take method---> take()
#
# - use to retrive spacific columns or rows data
#
# - 1st argument: indices-- take list like values for row/column index number
#
# - it tries to extract the data
#
# - That value we provided repreasents columns or rows??
#
# - 2nd argument: Axis 0=row, 1=column (default axis=0)

# %%
visa_df.take(indices=[5],axis=1) # indices means value for rows (if axis =0) or values fro column (if axis=1)
# Out:
#        no_of_employees
# 0                14513
# 1                 2412
# 2                44444
# 3                   98
# 4                 1082
# ...                ...
# 25475             2601
# 25476             3274
# 25477             1121
# 25478             1918
# 25479             3195
#
# [25480 rows x 1 columns]

# %%
visa_df.take(indices=[100,200,300]) 
# it retrive 3 rows which having index 100,200,300
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take(indices=[25],axis=1)
# now this will check for 25th columnm value
# But we habe only 12 columns
# so we got error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 visa_df.take(indices=[25],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:891, in BaseBlockManager.take(self, indexer, axis, verify)
# ...

# %%
visa_df.take(indices=[2,5,7],axis=1) # valus of 2,5,7 index columns
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.take(indices=[2,5,7],axis=1).head()

# %%
# Q) we want to take 100,200,300 rows from 2,5,7 column
visa_df.take(indices=[100,200,300]).take(indices=[2,5,7],axis=1)
# here we need to take 2 take method(take.take)
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %% [markdown]
# ### loc and iloc method
#
# - usr to fatch dataset information using indexing

# %%
# visa_df.iloc[<rows>,<columns>]
# visa_df.iloc[start:stop, start:stop]
# visa_df.iloc[start:stop:step, start:stop:step]
# visa_df.iloc[[list of rows],[list of columns]] 

# Case-1: rows=[100,200,300] columns=[2,3,7]
# Case-2: rows=[100:105] columnns=[2,5,7]
# case-3: rorws=[100:105] columns[2:7]
# case-4: rows=[100,200,300] columns=[2:7]
# case-5: rows=[100,200,300] column=:(all)
# case-6: rows=:(all) columns=[2,5,7]

# %%
visa_df.iloc[[100,200,300],[2,5,7]]
# 100,200,300 row number and 2,5,7 column no.
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %%
visa_df.iloc[100:105, [2, 5, 7]] 
# 100 to 105 rows with 2,5,7 clumns
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 101              Master's              334              Midwest
# 102            Bachelor's              224              Midwest
# 103             Doctorate              367                 West
# 104              Master's              306            Northeast

# %%
visa_df.iloc[100:105,2:7] 
# rows: 100 to 105 columns: 3 to 7
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 101              334         2007
# 102              224         2008
# 103              367         1982
# 104              306         2003

# %%
visa_df.iloc[[100,200,300],2:7]
# row no: 100,200,300, columns: 2 to 7
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 200             Doctorate                  Y                     N
# 300              Master's                  Y                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 200             3282         1979
# 300             3268         2012

# %%
visa_df.iloc[[100,200,300],:]
# rows: 100,200,300, columns: all
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[:,[2,5,7]]
# rows: all columns no: 2,5,7
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.iloc[100:110:3,2:5]
# gap of 2-2 rows
# Out:
#     education_of_employee has_job_experience requires_job_training
# 100              Master's                  Y                     N
# 103             Doctorate                  Y                     N
# 106            Bachelor's                  N                     N
# 109            Bachelor's                  Y                     N

# %%
visa_df.iloc[:] # all data
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[:,[2]]
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %%
# All in one 
visa_df.iloc[[2,5,7]] # rows
visa_df.iloc[:,[2,5,7]] # columns
# visa_df.iloc[:,2] # only 2nd column but series type
# visa_df.iloc[:,[2]] # datafram type
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# ### loc mathod---> loc[]
#
# - it is use to fatch dataset information using column name

# %%
visa_df.loc[[100,200],['case_status','education_of_employee']]
# Out:
#     case_status education_of_employee
# 100   Certified              Master's
# 200   Certified             Doctorate
